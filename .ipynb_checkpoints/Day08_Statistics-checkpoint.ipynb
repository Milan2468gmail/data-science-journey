# %%
# Important required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import warnings
warnings.filterwarnings('ignore')

# Load dataset
df = pd.read_csv('train.csv')

# Handle missing values
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# Drop irrelevent column
df = df.drop('Cabin', axis=1)

# Preview dataset shape
print('Shape:', df.shape)

df.head()
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# Shape: (891, 11)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# ...

# %% [markdown]
# ## Descriptive Statistics

# %%
age = df['Age']

print(f'Count: {age.count()}')
print(f'Mean: {age.mean():.2f}')
print(f'Median: {age.median():.2f}')
print(f'Mode: {age.mode()[0]:.2f}')
print(f'Std Dev: {age.std():.2f}')
print(f'Min: {age.min():.2f}')
print(f'Max: {age.max():.2f}')
print(f'Q1: {age.quantile(0.25):.2f}')
print(f'Q3: {age.quantile(0.75):.2f}')
print(f'IQR: {age.quantile(0.75) - age.quantile(0.25):.2f}')
# Out:
# Count: 891
# Mean: 29.36
# Median: 28.00
# Mode: 28.00
# Std Dev: 13.02
# Min: 0.42
# Max: 80.00
# Q1: 22.00
# Q3: 35.00
# IQR: 13.00

# %% [markdown]
# ### Insight
# The average age of passengers is close to the median, indicationg a relatively balanced distribution with slight skewness. The presence of a noticeable standard deviation suggests variability in passenger ages. Additionally, the interquartile range(IQR) highlights the spread of the middle 50% of the data, while the difference between maximum and minimum values indicates the presence of both very young and older passengers.

# %% [markdown]
# ## Mean vs Median: Why Median is Preferred for Skewed data

# %%
# Example to demonstrate effect of outliers on mean vs median

salaries = [30000, 32000, 35000, 28000, 31000, 33000]
with_ceo = [30000,32000,35000,28000,31000,33000,5000000]

print('WITHOUT the CEO:')
print(f' Mean = {int(sum(salaries)/len(salaries)):,}')
print(f' Median = {int(sorted(salaries)[len(salaries)//2]):,}')

print('\nWITH the CEO salary added:')
print(f' Mean = {int(sum(with_ceo)/len(with_ceo)):,}')
print(f' Median = {int(sorted(with_ceo)[len(with_ceo)//2]):,}')

print('\nRULE:')
print('Use MEDIAN when data has outliers.')
print('Use MEAN when data is symmetric.')

print('\nTitanic Fare Analysis:')
print(f'Fare Mean = {df["Fare"].mean():.2f}')
print(f'Fare Median = {df["Fare"].median():.2f}')
# Out:
# WITHOUT the CEO:
#  Mean = 31,500
#  Median = 32,000
#
# WITH the CEO salary added:
#  Mean = 741,285
#  Median = 32,000
#
# RULE:
# Use MEDIAN when data has outliers.
# Use MEAN when data is symmetric.
#
# Titanic Fare Analysis:
# Fare Mean = 32.20
# Fare Median = 14.45

# %% [markdown]
# ### Insight
# This example demonstrates the impact of outliers on statistical measures. When an extreme value (CEO salary) is introduced, the mean increases significantly, while the median remains relatively stable. This highlights that the median is more robust to outliers. Similarly, in the Titanic dataset, the difference between fare mean and median suggests that fare distribution is skewed, making the median a more reliable measure of central tendency.

# %% [markdown]
# ## Distribution Analysis: Age and Fare

# %%
# Visualize distributions of Age and Fare 
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Left chart : Age distribution
axes[0].hist(df['Age'], bins=25, color='steelblue', edgecolor='white')

axes[0].axvline(df['Age'].mean(), color='red', linestyle='--', 
                label=f'Mean: {df["Age"].mean():.1f}')

axes[0].axvline(df['Age'].median(), color='green', linestyle='-', 
                label=f'Median: {df["Age"].median():.1f}')

axes[0].set_title('Age Distribution', fontweight='bold')

axes[0].set_xlabel('Age')

axes[0].legend()

# Right chart : Fare distribution

axes[1].hist(df['Fare'], bins=30, color='orange', edgecolor='white')

axes[1].axvline(df['Fare'].mean(), color='red', linestyle='--', 
                label=f'Mean: {df["Fare"].mean():.1f}')

axes[1].axvline(df['Fare'].median(), color='green', linestyle='-', 
                label=f'Median: {df["Fare"].median():.1f}')

axes[1].set_title('Fare Distribution', fontweight='bold')

axes[1].set_xlabel('Fare (pounds)')

axes[1].set_ylabel('Count')

axes[1].set_xlim(0, 200)

axes[1].legend()

plt.tight_layout()

plt.savefig('stats_distributions.png', dpi=100)

plt.show()

# %% [markdown]
# ### Insight
# The age distribution shows that most passengers fall within the 20-35 age range, indicating a concentration of young adults. The mean and median are close, suggesting a relatively symmetric distribution.
#
# In contrast, the fare distribution is highly right-skewed, as the mean is significantly higher than the median. This indicates the presence of high-value outliers, meaning a small pf passengers paid very high fares.

# %% [markdown]
# ## Correlation Analysis: Relationships Between Variables

# %%
# Select numerical columns for correlation analysis

cols = ['Survived', 'Pclass', 'Age', 'SibSp', 'Fare' ]

corr = df[cols].corr()

print('CORRELATON MATRIX:')
print(corr.round(2))

print('\nInterpretation Guide:')
print('Near +1 -> strong positive relationship')
print('Near 0 -> little or no relationship')
print('Near -1 -> strong negative relationship')

print('\nKey Relationships:')
print(f'Fare vs Survived: {corr.loc["Survived", "Fare"]:.2f}')
print(f'Pclass vs Survived: {corr.loc["Survived", "Pclass"]:.2f}')
print(f'Age vs Survived: {corr.loc["Survived", "Age"]:.2f}')

# Heatmap visualization
fig, ax = plt.subplots(figsize=(8, 6))

sns.heatmap(
    corr,
    annot=True,
    fmt='.2f',
    cmap='RdYlGn',
    center=0,
    square=True,
    linewidths=0.5,
    ax=ax)

ax.set_title('Factors Affecting Survival', fontweight='bold')

plt.tight_layout()
plt.savefig('stats_heatmap.png', dpi=100)
plt.show()
# Out:
# CORRELATON MATRIX:
#           Survived  Pclass   Age  SibSp  Fare
# Survived      1.00   -0.34 -0.06  -0.04  0.26
# Pclass       -0.34    1.00 -0.34   0.08 -0.55
# Age          -0.06   -0.34  1.00  -0.23  0.10
# SibSp        -0.04    0.08 -0.23   1.00  0.16
# Fare          0.26   -0.55  0.10   0.16  1.00
#
# Interpretation Guide:
# Near +1 -> strong positive relationship
# Near 0 -> little or no relationship
# Near -1 -> strong negative relationship
#
# Key Relationships:
# Fare vs Survived: 0.26
# Pclass vs Survived: -0.34
# Age vs Survived: -0.06

# %% [markdown]
# ### Insight
#
# Fare shows a positive correlation with survival, indicating that passengers who paid higher fares more likely to survive. This suggests that socioeconomic status played an important role in survival outcomes.

# %% [markdown]
# ## Hypothesis Testing: Is the Difference in class Survival Statistically Significant?

# %%
# Compare survival rates between first and third class passengers

first = df[df['Pclass']==1]['Survived']
third = df[df['Pclass']==3]['Survived']

print(f'First class survival: {first.mean()*100:.1f}%')
print(f'Third class survival: {third.mean()*100:.1f}%')

# Run t-test
t, p = stats.ttest_ind(first, third)

print(f'P-value: {p:.6f}')
print()

print('Interpretation:')
print(' p < 0.05 -> statistically significant difference (not due by chance)')
print(' p > 0.05 -> no significant (could be random)')

if p < 0.05: 
    print('RESULT: YES - class significantly affected survival:')
    print('The difference between first and third class is NOT by chance.')
else : 
    print('RESULTL: NO significant difference found.')
# Out:
# First class survival: 63.0%
# Third class survival: 24.2%
# P-value: 0.000000
#
# Interpretation:
#  p < 0.05 -> statistically significant difference (not due by chance)
#  p > 0.05 -> no significant (could be random)
# RESULT: YES - class significantly affected survival:
# The difference between first and third class is NOT by chance.

# %% [markdown]
# ### Insight
#
# The hypothesis test shows that the difference in survival rates between first-class and third-class passengers is statistically significant(p < 0.05). This indicates that the observed difference is unlikely to be due to random chance. Therefore, passenger class had a meaningful impact on survival probability.

# %% [markdown]
# ## Outlier Detection Using the IQR Method

# %%
# Define a reusable function to detect outliers using the IQR method

def find_outliers(column, name):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    
    low = Q1 - 1.5 * IQR
    high = Q3 + 1.5 * IQR
    
    out = column[(column < low) | (column > high)]
    
    print(f'{name}: {len(out)} outliers found')
    print(f' Normal range: {low:.1f} to {high:.1f}')
    print()

# Apply the function to selected columns
find_outliers(df['Age'], 'Age')
find_outliers(df['Fare'], 'Fare')
find_outliers(df['SibSp'], 'SibSp')
# Out:
# Age: 66 outliers found
#  Normal range: 2.5 to 54.5
#
# Fare: 116 outliers found
#  Normal range: -26.7 to 65.6
#
# SibSp: 46 outliers found
#  Normal range: -1.5 to 2.5

# %% [markdown]
# ### Insight
#
# The IQR method identifies values that lie significantly outside the normal range of the data. The presence of outliers in the Fare column indicates that some passengers paid unusually high amounts, which may influence statistical measures such as the mean. In contrast, Age and SibSp show fewer extreme values, suggesting a more consistent distribution.

# %% [markdown]
# ## Statistical Summary

# %%
print('='*50)
print('STATISTICS CHEAT SHEET')
print('='*50)

print('\nCENTRAL TENDENCY:')
print('Mean = average (use for symmetric data)')
print('Median = middle value (use when outliers exist)')
print('Mode = most frequent value')

print('\nDISPERSION:')
print('Standard Deviation = average distance from the mean')
print('IQR = Q3 - Q1 (spread of middle 50%)')

print('\nCORRELATION:')
print('+1 -> perfect positive relationship')
print('-1 -> perfect negative relationship')
print('0 -> no relationship.')
print('WARNING: Correlation does NOT imply causation')

print('\nHYPOTHESIS TESTING:')
print('p < 0.05 -> statistically significant result')
print('p > 0.05 -> result may be due to chance')

print('\nOUTLIERS:')
print('IQR method: values below Q1 - 1.5*IQR or above Q3 + 1.5*IQR.')

print('\nDay 8 COMPLETE! Statistics analysis finished.')
# Out:
# ...
# STATISTICS CHEAT SHEET
# ...
#
# CENTRAL TENDENCY:
# Mean = average (use for symmetric data)
# Median = middle value (use when outliers exist)
# Mode = most frequent value
#
# DISPERSION:
# Standard Deviation = average distance from the mean
# IQR = Q3 - Q1 (spread of middle 50%)
#
# CORRELATION:
# +1 -> perfect positive relationship
# -1 -> perfect negative relationship
# 0 -> no relationship.
# WARNING: Correlation does NOT imply causation
#
# HYPOTHESIS TESTING:
# p < 0.05 -> statistically significant result
# p > 0.05 -> result may be due to chance
#
# OUTLIERS:
# IQR method: values below Q1 - 1.5*IQR or above Q3 + 1.5*IQR.
#
# Day 8 COMPLETE! Statistics analysis finished.

# %% [markdown]
# ## Final Conclusion
#
# The statistical analysis of the Titanic dataset reveals that survival was strongly influenced by socioeconomic factors such as passenger class and fare. While age showed some variation, it had a weaker impact on survival. The presence of fkewness and outliers highlights the importance of using appropriate statistical measures such as median and IQR. Overall, this analysis demonstrates how statistical techniques can uncover meaningful patterns in real-world data.
